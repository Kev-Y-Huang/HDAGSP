# %%
import pandas as pd
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt
import datetime

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA

from sklearn.cluster import KMeans
from gap_statistic import OptimalK

# %%
game_data = pd.read_csv("Data/game_log.csv")

# %%
game_data.describe()
# Out:
#          home_goals    away_goals
# count  20736.000000  20736.000000
# mean       1.652440      1.227768
# std        1.277547      1.134360
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       10.000000      9.000000

# %%
game_data.head(10)
# Out:
#               dateTime          League  home_goals  away_goals  \
# 0  2007-09-15 11:00:00  Premier League           0           1
# 1  2007-09-15 12:30:00  Premier League           1           3
# 2  2007-09-15 14:00:00  Premier League           1           0
# 3  2007-09-15 14:00:00  Premier League           2           0
# 4  2007-09-15 14:00:00  Premier League           3           0
# 5  2007-09-15 16:15:00  Premier League           0           0
# 6  2007-09-16 15:00:00  Premier League           1           0
# 7  2007-09-17 19:00:00  Premier League           1           0
# 8  2007-09-22 14:00:00  Premier League           2           2
# 9  2007-09-22 14:00:00  Premier League           5           0
#
#               home_team             away_team
# 0            Everton FC  Manchester United FC
# 1  Tottenham Hotspur FC            Arsenal FC
# 2    Birmingham City FC   Bolton Wanderers FC
# 3        Sunderland AFC            Reading FC
# 4    West Ham United FC      Middlesbrough FC
# 5            Chelsea FC   Blackburn Rovers FC
# 6    Manchester City FC        Aston Villa FC
# 7       Derby County FC   Newcastle United FC
# 8      Middlesbrough FC        Sunderland AFC
# 9            Arsenal FC       Derby County FC

# %%
def column_to_datetime(df, column):
    # Converts a column of a of a data frame to datetime
    df[column] = list(map(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'),   df[column]))

# %%
# Given goals for home team and away team add a new column with home team result Win, Draw or Loss 1 for win, 0 for tie etc 
def get_result(goal_diff):
    if goal_diff > 0:
        return 'Win'
    elif goal_diff == 0:
        return 'Tie'
    else:
        return 'Loss'
    
    
def win_loss(df):
    difference = df['home_goals'] - df['away_goals']
    result = list(map(lambda x: get_result(x), difference))
    df['home_team_result'] = result
    return df

# %%
column_to_datetime(game_data, 'dateTime')

# %%
game_data = win_loss(game_data)

# %%
game_data.head(20)
# Out:
#               dateTime          League  home_goals  away_goals  \
# 0  2007-09-15 11:00:00  Premier League           0           1
# 1  2007-09-15 12:30:00  Premier League           1           3
# 2  2007-09-15 14:00:00  Premier League           1           0
# 3  2007-09-15 14:00:00  Premier League           2           0
# 4  2007-09-15 14:00:00  Premier League           3           0
# 5  2007-09-15 16:15:00  Premier League           0           0
# 6  2007-09-16 15:00:00  Premier League           1           0
# 7  2007-09-17 19:00:00  Premier League           1           0
# 8  2007-09-22 14:00:00  Premier League           2           2
# 9  2007-09-22 14:00:00  Premier League           5           0
# 10 2007-09-22 16:15:00  Premier League           3           3
# 11 2007-09-23 13:00:00  Premier League           2           0
# 12 2007-09-23 12:30:00  Premier League           3           1
# 13 2007-09-23 14:00:00  Premier League           1           1
# 14 2007-09-23 14:00:00  Premier League           0           1
# 15 2007-09-23 15:00:00  Premier League           2           0
# 16 2007-09-29 11:45:00  Premier League           3           1
# 17 2007-09-29 14:00:00  Premier League           0           0
# 18 2007-09-29 14:00:00  Premier League           0           1
# 19 2007-09-29 14:00:00  Premier League           0           1
#
#                home_team             away_team home_team_result
# 0             Everton FC  Manchester United FC             Loss
# 1   Tottenham Hotspur FC            Arsenal FC             Loss
# 2     Birmingham City FC   Bolton Wanderers FC              Win
# 3         Sunderland AFC            Reading FC              Win
# 4     West Ham United FC      Middlesbrough FC              Win
# 5             Chelsea FC   Blackburn Rovers FC              Tie
# 6     Manchester City FC        Aston Villa FC              Win
# 7        Derby County FC   Newcastle United FC              Win
# 8       Middlesbrough FC        Sunderland AFC              Tie
# 9             Arsenal FC       Derby County FC              Win
# 10             Fulham FC    Manchester City FC              Tie
# 11        Aston Villa FC            Everton FC              Win
# 12   Newcastle United FC    West Ham United FC              Win
# 13   Bolton Wanderers FC  Tottenham Hotspur FC              Tie
# 14   Blackburn Rovers FC         Portsmouth FC             Loss
# 15  Manchester United FC            Chelsea FC              Win
# 16    Manchester City FC   Newcastle United FC              Win
# 17            Chelsea FC             Fulham FC              Tie
# 18    West Ham United FC            Arsenal FC             Loss
# 19     Wigan Athletic FC          Liverpool FC             Loss

# %%
# Output number of games for each team 
for league in game_data['League'].unique():
    print(league)
    print(sum(game_data['League'] == league))
    
# Convert Outputs to pandas table
# Out:
# Premier League
# 4305
# Primera Division
# 4380
# Bundesliga
# 3527
# Serie A
# 4353
# Ligue 1
# 4171

# %%
# Print Number of teams in Dataset for each league 
for league in game_data['League'].unique():
    print(league)
    print(len(game_data[game_data['League'] == league]['home_team'].unique()))
# Out:
# Premier League
# 38
# Primera Division
# 38
# Bundesliga
# 34
# Serie A
# 35
# Ligue 1
# 38

# %%
games = game_data[game_data['League'] == 'Premier League']['home_team'].value_counts() #.groupby(['away_team']).count()
games
# Out:
# Manchester City FC            225
# Chelsea FC                    224
# Manchester United FC          221
# Liverpool FC                  219
# Everton FC                    219
# Tottenham Hotspur FC          217
# Arsenal FC                    215
# West Ham United FC            201
# Newcastle United FC           183
# Stoke City FC                 176
# Sunderland AFC                172
# West Bromwich Albion FC       159
# Aston Villa FC                156
# Fulham FC                     142
# Southampton FC                128
# Swansea City AFC              124
# Crystal Palace FC             110
# Burnley FC                     95
# Wigan Athletic FC              94
# Leicester City FC              93
# Hull City AFC                  87
# Bolton Wanderers FC            85
# Blackburn Rovers FC            83
# Wolverhampton Wanderers FC     78
# AFC Bournemouth                77
# Norwich City FC                75
# Watford FC                     72
# Queens Park Rangers FC         51
# Birmingham City FC             50
# Middlesbrough FC               47
# Portsmouth FC                  46
# Brighton & Hove Albion FC      41
# Huddersfield Town FC           36
# Cardiff City FC                34
# Reading FC                     29
# Blackpool FC                   18
# Derby County FC                17
# Sheffield United FC             6
# Name: home_team, dtype: int64

# %% [markdown]
# Top teams have many more games played

# %%
game_data[game_data['League'] == 'Premier League']['away_team'].value_counts()
# Out:
# Arsenal FC                    223
# Tottenham Hotspur FC          219
# Manchester United FC          217
# Chelsea FC                    215
# Manchester City FC            214
# Liverpool FC                  211
# Everton FC                    208
# West Ham United FC            199
# Newcastle United FC           182
# Stoke City FC                 175
# Sunderland AFC                174
# Aston Villa FC                163
# West Bromwich Albion FC       159
# Fulham FC                     131
# Southampton FC                128
# Swansea City AFC              125
# Crystal Palace FC             112
# Wigan Athletic FC             103
# Leicester City FC              97
# Burnley FC                     94
# Hull City AFC                  89
# Bolton Wanderers FC            87
# Blackburn Rovers FC            85
# Watford FC                     79
# Wolverhampton Wanderers FC     79
# AFC Bournemouth                78
# Norwich City FC                75
# Queens Park Rangers FC         55
# Birmingham City FC             51
# Middlesbrough FC               50
# Portsmouth FC                  46
# Brighton & Hove Albion FC      41
# Cardiff City FC                37
# Huddersfield Town FC           35
# Reading FC                     34
# Blackpool FC                   18
# Derby County FC                12
# Sheffield United FC             5
# Name: away_team, dtype: int64

# %%
game_data['dateTime'][-1:]
# Out:
# 20735   2019-11-10 20:00:00
# Name: dateTime, dtype: datetime64[ns]

# %% [markdown]
# Games up to Novermber 10, 2019

# %%
# Get all games for a team 
game_data[(game_data['home_team']== 'Manchester United FC') | (game_data['away_team'] == 'Manchester United FC')]
# Out:
#                 dateTime          League  home_goals  away_goals  \
# 0    2007-09-15 11:00:00  Premier League           0           1
# 15   2007-09-23 15:00:00  Premier League           2           0
# 20   2007-09-29 16:15:00  Premier League           0           1
# 26   2007-10-06 11:45:00  Premier League           4           0
# 41   2007-10-20 16:15:00  Premier League           1           4
# ...                  ...             ...         ...         ...
# 4266 2019-10-06 15:30:00  Premier League           1           0
# 4274 2019-10-20 15:30:00  Premier League           1           1
# 4284 2019-10-27 16:30:00  Premier League           1           3
# 4285 2019-11-02 12:30:00  Premier League           1           0
# 4302 2019-11-10 14:00:00  Premier League           3           1
#
#                  home_team                  away_team home_team_result
# 0               Everton FC       Manchester United FC             Loss
# 15    Manchester United FC                 Chelsea FC              Win
# 20      Birmingham City FC       Manchester United FC             Loss
# 26    Manchester United FC          Wigan Athletic FC              Win
# 41          Aston Villa FC       Manchester United FC             Loss
# ...                    ...                        ...              ...
# 4266   Newcastle United FC       Manchester United FC              Win
# 4274  Manchester United FC               Liverpool FC              Tie
# 4284       Norwich City FC       Manchester United FC             Loss
# 4285       AFC Bournemouth       Manchester United FC              Win
# 4302  Manchester United FC  Brighton & Hove Albion FC              Win
#
# [438 rows x 7 columns]

# %%
def get_team_games(df, team_name, start, end):
    games = game_data[(game_data['home_team']== team_name) | (game_data['away_team'] == team_name)]
    games = games[games['dateTime'] >= start]
    games = games[games['dateTime'] <= end]
    return games

# %%
# Absolute endpoints of time period
START = min(game_data['dateTime'])
END = max(game_data['dateTime'])

# %%
team_name = "Arsenal FC"
arsenal_games = get_team_games(game_data, team_name, START, END)
arsenal_games.head(10)
# Out:
#               dateTime          League  home_goals  away_goals  \
# 1  2007-09-15 12:30:00  Premier League           1           3
# 9  2007-09-22 14:00:00  Premier League           5           0
# 18 2007-09-29 14:00:00  Premier League           0           1
# 28 2007-10-07 11:00:00  Premier League           3           2
# 40 2007-10-20 14:00:00  Premier League           2           0
# 52 2007-10-28 16:00:00  Premier League           1           1
# 53 2007-11-03 12:45:00  Premier League           2           2
# 62 2007-11-12 20:00:00  Premier League           1           3
# 74 2007-11-24 15:00:00  Premier League           2           0
# 84 2007-12-01 17:15:00  Premier League           1           2
#
#                home_team             away_team home_team_result
# 1   Tottenham Hotspur FC            Arsenal FC             Loss
# 9             Arsenal FC       Derby County FC              Win
# 18    West Ham United FC            Arsenal FC             Loss
# 28            Arsenal FC        Sunderland AFC              Win
# 40            Arsenal FC   Bolton Wanderers FC              Win
# 52          Liverpool FC            Arsenal FC              Tie
# 53            Arsenal FC  Manchester United FC              Tie
# 62            Reading FC            Arsenal FC             Loss
# 74            Arsenal FC     Wigan Athletic FC              Win
# 84        Aston Villa FC            Arsenal FC             Loss

# %%
# Get goal scoring stats for a team during a certain time period
def get_scoring_statistics(df, team_name, start, end):
    team_games = get_team_games(df, team_name, start, end)
    home_goals = team_games[team_games['home_team'] == team_name]['home_goals'].mean()
    away_goals = team_games[team_games['away_team'] == team_name]['away_goals'].mean()
    home_conceded = team_games[team_games['away_team'] != team_name]['away_goals'].mean()
    away_conceded = team_games[team_games['home_team'] != team_name]['home_goals'].mean()
    print("Goals Scored at Home: {0:.2f}".format(home_goals))
    print("Goals Scored Away: {0:.2f}".format(away_goals))
    print("Goals Conceded at Home: {0:.2f}".format(home_conceded))
    print("Goals Conceded Away: {0:.2f}".format(away_conceded))

# %%
get_scoring_statistics(game_data, "Manchester United FC", START, END)
# Out:
# Goals Scored at Home: 2.22
# Goals Scored Away: 1.70
# Goals Conceded at Home: 0.81
# Goals Conceded Away: 1.12

# %%
get_scoring_statistics(game_data, "Manchester City FC", START, END)
# Out:
# Goals Scored at Home: 2.51
# Goals Scored Away: 1.85
# Goals Conceded at Home: 0.86
# Goals Conceded Away: 1.25

# %%
# Look at scoring trends over last 30 days 
start_day  = END - datetime.timedelta(days = 30)
get_scoring_statistics(game_data, "Manchester City FC", start_day, END)
# Out:
# Goals Scored at Home: 2.50
# Goals Scored Away: 1.50
# Goals Conceded at Home: 0.50
# Goals Conceded Away: 1.50
